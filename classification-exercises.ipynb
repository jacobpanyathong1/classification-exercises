# %%
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import os 
import seaborn as sns
import acquire# acquire.py
import matplotlib.pyplot as plt
import prepare # prepare.py

# %config InlineBackend.figure_format='retina'

# %% [markdown]
#    #### I. Data Aquisition Exercises

# %%
df_iris = data('iris)       # Acquiring DataFrame for iris

# %%
df_iris         # Iris DataFrame
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
df_iris.shape  # shape of DataFrame
# Out:
# (150, 5)

# %%
df_iris.columns # All columns in iris
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df_iris.columns.to_list()
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df_iris.describe() # Summary statistics
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ##### Google Sheet DataFrame

# %%
df_google = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'
# URL DataFrame

# %%
csv_export_url = df_google.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_google = pd.read_csv(csv_export_url)
df_google.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_google.nunique(dropna=True)
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# ##### Excel File Train Dataset

# %%
df_excel = pd.read_excel('train.xlsx')

# %%
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# ##### Assigning the first 100 rows to the new Excel DataFrame.

# %%
df_excel_sample = df_excel.loc[0:100] # Assigning the first 100 rows to the new excel DataFrame.

# %%
df_excel.count(axis=0)[1] # number of rows in original DataFrame.

# %%
df_excel.columns[0:5] # First 5 rows of excel columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %%
series_excel = df_excel.dtypes
series_excel
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
series_excel.loc[['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']] # Name of columns with object dtypes.
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# ### Passenger Id

# %%
df_excel.nsmallest(1,'PassengerId') # Min value
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df_excel.nlargest(1,'PassengerId') # Max value
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
a = df_excel.iloc[0,0] # PassengerId min value
a
# Out:
# 1

# %%
b = df_excel.iloc[890,0] # PassengerId max value
b
# Out:
# 891

# %%
b-a # Range
# Out:
# 890

# %% [markdown]
# #### Conclusion of Data Aqcuisition

# %% [markdown]
# ### Survived

# %%
df_excel.nsmallest(1,'Survived')
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df_excel.nlargest(1,'Survived')
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
a = df_excel.iloc[0,1] # PassengerId min value
a
# Out:
# 0

# %%
b = df_excel.iloc[1,1] # PassengerId min value
b
# Out:
# 1

# %%
b-a # Range
# Out:
# 1

# %% [markdown]
# ### Pclass

# %%
df_excel.nsmallest(1,'Pclass')
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
df_excel.nlargest(1,'Pclass')
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# ### Age

# %%
df_excel.nsmallest(1,'Age')
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
df_excel.nlargest(1,'Age')
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
a = df_excel.iloc[803, 5]

# %%
b = df_excel.iloc[630, 5]

# %%
b-a
# Out:
# 79.58

# %% [markdown]
# ### SibSP

# %%
df_excel.nsmallest(1,'SibSp')
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df_excel.nlargest(1,'SibSp')
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex  Age  \
# 159          160         0       3  Sage, Master. Thomas Henry  male  NaN
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked
# 159      8      2  CA. 2343  69.55   NaN        S

# %%
a = df_excel.iloc[2, 6]
a
# Out:
# 0

# %%
b = df_excel.iloc[159, 6]
b
# Out:
# 8

# %%
b-a
# Out:
# 8

# %% [markdown]
# ### Parch

# %%
df_excel.nsmallest(1,'Parch')
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df_excel.nlargest(1,'Parch')
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 678  female  43.0      1      6  CA 2144  46.9   NaN        S

# %%
a = df_excel.iloc[0, 7]

# %%
b = df_excel.iloc[678, 7]

# %%
b-a
# Out:
# 6

# %% [markdown]
# ### Fare

# %%
df_excel.nsmallest(1,'Fare')
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 179          180         0       3  Leonard, Mr. Lionel  male  36.0      0
#
#      Parch Ticket  Fare Cabin Embarked
# 179      0   LINE   0.0   NaN        S

# %%
df_excel.nlargest(1,'Parch')
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 678  female  43.0      1      6  CA 2144  46.9   NaN        S

# %%
a = df_excel.iloc[179, 9]

# %%
b = df_excel.iloc[678, 9]

# %%
b-a
# Out:
# 46.9

# %% [markdown]
# ## Conclusion

# %%
import env

def get_connection(db, user=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

df = pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))

df.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %%
import acquire

# %%
def get_titanic_data():
    return pd.read_sql('SELECT * FROM passengers', get_connection('titanic_db'))

# %%
get_titanic_data()
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %%
acquire.get_titanic()
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class deck  embark_town  alone
# ...

# %%
acquire.get_iris()
# Out:
#      Unnamed: 0  species_id  measurement_id  sepal_length  sepal_width  \
# 0             0           1               1           5.1          3.5
# 1             1           1               2           4.9          3.0
# 2             2           1               3           4.7          3.2
# 3             3           1               4           4.6          3.1
# 4             4           1               5           5.0          3.6
# 5             5           1               6           5.4          3.9
# 6             6           1               7           4.6          3.4
# 7             7           1               8           5.0          3.4
# 8             8           1               9           4.4          2.9
# 9             9           1              10           4.9          3.1
# 10           10           1              11           5.4          3.7
# 11           11           1              12           4.8          3.4
# ...

# %% [markdown]
# ## II. Data Preparation

# %% [markdown]
# ### Titanic Dataset

# %% [markdown]
# #### //Cleaning

# %%
# Summarize Data
iris_df = acquire.get_iris()

# %%
iris_df.head()
# Out:
#    Unnamed: 0  species_id  measurement_id  sepal_length  sepal_width  \
# 0           0           1               1           5.1          3.5
# 1           1           1               2           4.9          3.0
# 2           2           1               3           4.7          3.2
# 3           3           1               4           4.6          3.1
# 4           4           1               5           5.0          3.6
#
#    petal_length  petal_width species_name
# 0           1.4          0.2       setosa
# 1           1.4          0.2       setosa
# 2           1.3          0.2       setosa
# 3           1.5          0.2       setosa
# 4           1.4          0.2       setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      150 non-null    int64
#  1   species_id      150 non-null    int64
#  2   measurement_id  150 non-null    int64
#  3   sepal_length    150 non-null    float64
#  4   sepal_width     150 non-null    float64
#  5   petal_length    150 non-null    float64
#  6   petal_width     150 non-null    float64
#  7   species_name    150 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 9.5+ KB

# %%
iris_df.columns
# Out:
# Index(['Unnamed: 0', 'species_id', 'measurement_id', 'sepal_length',
#        'sepal_width', 'petal_length', 'petal_width', 'species_name'],
#       dtype='object')

# %%
to_drop = iris_df.columns[1]
to_drop
# Out:
# 'species_id'

# %%
iris_df.drop(columns=to_drop, inplace=True)

# %%
iris_df.isna().sum()
# Out:
# Unnamed: 0      0
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species_name    0
# dtype: int64

# %%
iris_df= iris_df.rename(columns={'species_name': 'species'})

# %%
iris_df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# 5             5           5.4          3.9           1.7          0.4
# 6             6           4.6          3.4           1.4          0.3
# 7             7           5.0          3.4           1.5          0.2
# 8             8           4.4          2.9           1.4          0.2
# 9             9           4.9          3.1           1.5          0.1
# 10           10           5.4          3.7           1.5          0.2
# 11           11           4.8          3.4           1.6          0.2
# ...

# %%
dummies = pd.get_dummies(iris_df[['species']])
dummies
# Out:
#      species_setosa  species_versicolor  species_virginica
# 0                 1                   0                  0
# 1                 1                   0                  0
# 2                 1                   0                  0
# 3                 1                   0                  0
# 4                 1                   0                  0
# 5                 1                   0                  0
# 6                 1                   0                  0
# 7                 1                   0                  0
# 8                 1                   0                  0
# 9                 1                   0                  0
# 10                1                   0                  0
# 11                1                   0                  0
# 12                1                   0                  0
# 13                1                   0                  0
# 14                1                   0                  0
# ...

# %%
pd.concat([iris_df, dummies], axis=1)
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# 5             5           5.4          3.9           1.7          0.4
# 6             6           4.6          3.4           1.4          0.3
# 7             7           5.0          3.4           1.5          0.2
# 8             8           4.4          2.9           1.4          0.2
# 9             9           4.9          3.1           1.5          0.1
# 10           10           5.4          3.7           1.5          0.2
# 11           11           4.8          3.4           1.6          0.2
# ...

# %%
def prep_iris(df): 
    to_drop = df.columns[0:2]
    df.drop(columns=to_drop, inplace=True)
    species = df.rename(columns={'species_name': 'species'}, inplace=True)
    dummies = pd.get_dummies(df[['species']])
    df= pd.concat([df, dummies], axis=1)
    return df

# %%
prepped_iris= prep_iris(iris_df)
prepped_iris
# Out:
#      sepal_width  petal_length  petal_width     species  species_setosa  \
# 0            3.5           1.4          0.2      setosa               1
# 1            3.0           1.4          0.2      setosa               1
# 2            3.2           1.3          0.2      setosa               1
# 3            3.1           1.5          0.2      setosa               1
# 4            3.6           1.4          0.2      setosa               1
# 5            3.9           1.7          0.4      setosa               1
# 6            3.4           1.4          0.3      setosa               1
# 7            3.4           1.5          0.2      setosa               1
# 8            2.9           1.4          0.2      setosa               1
# 9            3.1           1.5          0.1      setosa               1
# 10           3.7           1.5          0.2      setosa               1
# 11           3.4           1.6          0.2      setosa               1
# ...

# %% [markdown]
# ### Titanic Dataset

# %% [markdown]
# #### //Cleaning

# %%
titanic_df = acquire.get_titanic()
titanic_df.head()

# %%
titanic_df.columns

# %%
#to_drop = titanic_df.columns[[0,-5, -3]]
#to_drop

# %%
#dummies = pd.get_dummies(titanic_df[['class', 'embark_town']])
#dummies

# %%
#pd.concat([titanic_df, dummies], axis=1)

# %%
def prep_titanic(df): 
    to_drop = df.columns[[0,-5, -3]]
    df.drop(columns=to_drop, inplace=True)
    dummies = pd.get_dummies(df[['class', 'embark_town']])
    df= pd.concat([df, dummies], axis=1) 
    return df

# %%
prepped_titanic = prep_titanic(titanic_df)

# %% [markdown]
# ### Telco Dataset

# %%
telco_df = acquire.get_telco_data()

# %%
def get_telco(df):
    df = acquire.get_telco_data()
    return df

# %%
telco_df.head()

# %%
telco_df.columns

# %%
#total_na = telco_df.isnull().sum() # Finding Nulls in dataset
#total_na

# %%
telco_df.info()

# %%
#telco_df.drop(columns=['internet_service_type_id.1', 'payment_type_id.1'], inplace=True) #Drop duplicate columns

# %%
telco_df.head()

# %%
#encoded_vars = pd.get_dummies(telco_df[['contract_type', 'internet_service_type', 'payment_type']])

# %%
#pd.set_option('display.max_columns', 500) # Display all columns

# %%
#telco_df = pd.concat([telco_df, encoded_vars], axis=1)
#telco_df.head()

# %%
# telco_df['total_charges'] = (telco_df.total_charges + '0').astype('float') # Change total charges to float

# %%
# telco_df['total_charges'].dtype

# %%
# telco_df['gender'] = telco_df.gender.map({'Female': 1, 'Male': 0})

# %%
# telco_df['partner'] = telco_df.partner.map({'Yes': 1, 'No': 0})

# %%
# telco_df['dependents'] = telco_df.dependents.map({'Yes': 1, 'No': 0})

# %%
# telco_df['phone_service'] = telco_df.phone_service.map({'Yes': 1, 'No': 0})

# %%
# telco_df['churn'] = telco_df.churn.map({'Yes': 1, 'No': 0})

# %%
#telco_df

# %%
def prep_telco(df):
    '''
     This function cleans the telco data to prepare for splitting
    '''
    df.drop(columns=['internet_service_type_id.1', 'payment_type_id.1'], inplace=True) #Drop duplicate columns
    encoded_vars = pd.get_dummies(df[['contract_type', 'internet_service_type', 'payment_type']])
    pd.set_option('display.max_columns', 500) # Display all columns
    df = pd.concat([telco_df, encoded_vars], axis=1)
    df['total_charges'] = (df.total_charges + '0').astype('float') # Change total charges to float
    df['total_charges'].dtype
    df['gender'] = df.gender.map({'Female': 1, 'Male': 0})
    df['partner'] = df.partner.map({'Yes': 1, 'No': 0})
    df['dependents'] = df.dependents.map({'Yes': 1, 'No': 0})
    df['phone_service'] = df.phone_service.map({'Yes': 1, 'No': 0})
    df['churn'] = df.churn.map({'Yes': 1, 'No': 0})
    return df

# %% [markdown]
# ### Split the data

# %% [markdown]
# #### Telco

# %%
prepared_telco_data = prep_telco(telco_df)

# %%
#from prepare import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(prepared_telco_data, test_size=.2, random_state=123, stratify=telco_df.churn)

# %%
train

# %%
test

# %%
train.shape, test.shape

# %% [markdown]
# #### Iris

# %%
train_validate, test_iris = train_test_split(iris_df, test_size=.2, random_state=123, stratify=prepped_iris.species)
    
# splits train_validate into train and validate using train_test_split() stratifying on species to get an even mix of each species
train_iris, validate_iris = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate.species)

# %%
train_iris, validate_iris, test_iris
# Out:
# (     sepal_width  petal_length  petal_width     species
#  79           2.6           3.5          1.0  versicolor
#  36           3.5           1.3          0.2      setosa
#  133          2.8           5.1          1.5   virginica
#  95           3.0           4.2          1.2  versicolor
#  18           3.8           1.7          0.3      setosa
#  139          3.1           5.4          2.1   virginica
#  20           3.4           1.7          0.2      setosa
#  31           3.4           1.5          0.4      setosa
#  6            3.4           1.4          0.3      setosa
#  115          3.2           5.3          2.3   virginica
#  91           3.0           4.6          1.4  versicolor
#  145          3.0           5.2          2.3   virginica
#  125          3.2           6.0          1.8   virginica
#  82           2.7           3.9          1.2  versicolor
#  126          2.8           4.8          1.8   virginica
# ...

# %% [markdown]
# ### Titanic

# %%
train_validate, test = train_test_split(titanic_df, test_size=.2, random_state=123, stratify=prepped_titanic['class'])
    
# splits train_validate into train and validate using train_test_split() stratifying on species to get an even mix of each species
train, validate = train_test_split(train_validate, 
                                       test_size=.3, 
                                       random_state=123, 
                                       stratify=train_validate['class'])

# %%
train.shape, validate.shape, test.shape

# %% [markdown]
# ### Univariate Stats

# %% [markdown]
# #### Iris_Train

# %%
train_iris, validate_iris, test_iris

# %%
train_iris.describe(include='all').T

# %%
num_vars = train_iris[['petal_length','petal_width']]

# %%
cat_vars = train_iris['species']

# %% [markdown]
# **Takeaways**
# - Virginica has the highest avg petal length and the most outliers in the data.
# - Setosa has the lowest avg petal length.

# %%
#print(cat_vars)
#print(train_iris['species'])
print(train_iris['species'].value_counts())
print(train_iris['species'].value_counts(normalize=True)*100)
sns.countplot(x=train_iris['species'], data=train_iris)
plt.show()

# %% [markdown]
# **Takeaways**
#
# - There are 28 occurences of each species in the train iris data

# %%
# plot
fig, ax = plt.subplots()
VP = ax.boxplot(x=train_iris['petal_length'], patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.8},
                boxprops={"facecolor": "#36C2FA", "edgecolor": "white",
                          "linewidth": 0.8},
                whiskerprops={"color": "#36C2FA", "linewidth": 1.5},
                capprops={"color": "#36C2FA", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
train_iris.describe()

# %% [markdown]
# #### Bivariate Stats

# %%
plt.title("Petal Width")
sns.barplot(x='species', y='petal_width', data=train_iris)
petal_width_avg = train_iris.petal_width.mean()
plt.axhline(petal_width_avg, label='species', linestyle='dotted')
plt.legend()
plt.show()

# %% [markdown]
# **Takeaways**
# - Virginica has the highest avg petal length and the most outliers in the data.
# - Setosa has the lowest avg petal length.

# %%
train_iris.describe(include='all').T

# %%
#avg_setosa = train_iris.loc[train_iris['species']== 'setosa'].mean()[2]

# %%
#avg_setosa

# %%
#train_iris.loc[train_iris['species']== 'versicolor']['petal_width']

# %%
#avg_versicolor

# %%
#avg_virginica = train_iris.loc[train_iris['species']== 'virginica'].mean()[2]

# %%
#avg_virginica

# %%
train_iris_pw_virginica = train_iris.loc[train_iris['species']== 'virginica']['petal_width']

# %%
train_iris_pw_versicolor = train_iris.loc[train_iris['species']== 'versicolor']['petal_width']

# %%
train_iris_pw_setosa = train_iris.loc[train_iris['species']== 'setosa']['petal_width']

# %%
stats.mannwhitneyu(train_iris_pw_virginica, train_iris_pw_versicolor) # Manwhy test for virginica and versicolor

# %%
stats.mannwhitneyu(train_iris_pw_versicolor, train_iris_pw_setosa) # Manwhy test for versicolor and setosa

# %%
stats.mannwhitneyu(x=train_iris_pw_virginica, y=train_iris_pw_setosa) # Manwhy test for virginica and setosa

# %% [markdown]
# **Takeaways**
# $H_0$ : There is no siginifant difference between the species.
# $H_a$ : There is no siginifant difference between the species.
# With α = .05, our p-value is significantly below the α and with confidence we can reject the $H_0$ hypothesis that there is a significant difference between the species petal width.

# %% [markdown]
# ### Multivirate

# %%
plt.figure()
sns.pairplot(data=train_iris, hue='species', corner=True)

# %%
sns.catplot(x="petal_length", y="petal_width", data=train_iris, hue="species")

# %%
sns.relplot(x="petal_width", y="petal_length", hue="species", data=train_iris, height=6, aspect=1)
plt.xlim(0, 5)
# Out:
# (0.0, 5.0)

# %%
melted = train_iris.melt(id_vars=['species'],
               var_name='measures',
               value_name='values')
plt.title('Difference in Measurements across Species')
sns.swarmplot(x='measures',
             y='values',
             data=melted,
             hue='species'
             )
plt.xticks(rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.swarmplot(data=train_iris, x="petal_length",y="petal_length")

# %% [markdown]
# ### Part II

# %%
titanic_df = acquire.get_titanic()

# %%
# list of categorical variables to plot with survived
cat_vars = ['survived', 'pclass', 'sex', 'sibsp', 'parch', 'alone']
#compute survival rate
survival_rate = train.survived.mean()

# plot one variable with survived
col = 'pclass'
sns.barplot(x=col, y='survived', data=train, color='skyblue')
#add horizontal line with the overall survived rate
plt.axhline(survival_rate, color='rebbecapurple', linestyle='-.')

# make that work for the loop of all categorical variables
for col in cat_vars:
    sns.barplot(x=col, y='survivd', data=train, color='skyblue')
    plt.axhline()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 train, test, split = train_test_split(titanic_df)
#
# ValueError: not enough values to unpack (expected 3, got 2)
